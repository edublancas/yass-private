# %%
# %matplotlib inline

import numpy as np
from neural_noise import plot, load

# %%
import logging

import yass
from yass.preprocessing import Preprocessor
from yass.mainprocess import Mainprocessor

logging.basicConfig(level=logging.INFO)

# %%
data = load.data('/Users/edu/data/ucl-neuropixel/rawDataSample.bin',
                 n_channels=385,
                 data_format='wide',
                 dtype='int16')
# Out:
# /Users/edu/dev/grossman/neural-noise/src/neural_noise/load.py:32: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return data_reshaped if data_reshaped == 'long' else data_reshaped.T

# %%
geometry = np.load('/Users/edu/data/ucl-neuropixel/channel_positions.npy')

# %%
geometry.tofile('/Users/edu/data/ucl-neuropixel/neuropixel-geom.bin')

# %%
data.shape
# Out:
# (1800000, 385)

# %%
plot.multi_channel_series(data, channels=range(10),
                           time=1000, dt=100)

# %%
plot.series(data, channel=0, time=1000, dt=100)

# %%
data.tofile('/Users/edu/data/ucl-neuropixel/neuropixel.bin')

# %%
cfg = yass.Config.from_yaml('..config/threshold_neuropixel.yaml')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-1c31672d8a06> in <module>()
# ----> 1 cfg = yass.Config.from_yaml('threshold_neuropixel.yaml')
#
# ~/dev/grossman/YASS/src/yass/config.py in from_yaml(cls, path_to_file)
#      16     def from_yaml(cls, path_to_file):
#      17         # load config file
# ---> 18         with open(path_to_file) as f:
#      19             mapping = yaml.load(f)
#      20
#
# FileNotFoundError: [Errno 2] No such file or directory: 'threshold_neuropixel.yaml'
