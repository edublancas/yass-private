# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (18, 5)

# %%
def load(filename):
    df = pd.read_csv(filename, sep=' ',
                 names=['mem', 'usage', 'time'],
                skiprows=[0])
    return df

# %%
def plot(filename):
    df = load(filename)
    plt.plot(df.time, df.usage)

# %%
plot('mprofile_20180301000704.dat')

# %%
plot('mprofile_20180301000829.dat')
